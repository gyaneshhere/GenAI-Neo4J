# %%
from langchain.docstore.document import Document
from langchain.text_splitter import CharacterTextSplitter
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import Neo4jVector
from langchain_openai import OpenAIEmbeddings

# %%
loader = TextLoader("state_of_the_union.txt")

documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)
OPENAI_API_KEY="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"

# The base URL for your Azure OpenAI resource.  You can find this in the Azure portal under your Azure OpenAI resource.
os.environ['AZURE_OPENAI_ENDPOINT']
# The API key for your Azure OpenAI resource.  You can find this in the Azure portal under your Azure OpenAI resource.
os.environ['AZURE_OPENAI_API_KEY']
os.environ["OPENAI_API_VERSION"] = "2023-12-01-preview"
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

# The Neo4jVector Module will connect to Neo4j and create a vector index if needed.

db = Neo4jVector.from_documents(
    docs, OpenAIEmbeddings(openai_api_key=os.environ['AZURE_OP), url=url, username=username, password=password
)

query = "What did the president say about Ketanji Brown Jackson"
docs_with_score = db.similarity_search_with_score(query, k=2)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[92], line 17
#      13 embeddings = OpenAIEmbeddings(openai_api_key=os.environ['AZURE_OPENAI_API_KEY'])
#      15 # The Neo4jVector Module will connect to Neo4j and create a vector index if needed.
# ---> 17 db = Neo4jVector.from_documents(
#      18     docs, OpenAIEmbeddings(openai_api_key=os.environ['AZURE_OPENAI_API_KEY']), url=url, username=username, password=password
#      19 )
#      21 query = "What did the president say about Ketanji Brown Jackson"
#      22 docs_with_score = db.similarity_search_with_score(query, k=2)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/langchain_community/vectorstores/neo4j_vector.py:860, in Neo4jVector.from_documents(cls, documents, embedding, distance_strategy, ids, **kwargs)
#     857 texts = [d.page_content for d in documents]
# ...

# %%
print(docs_with_score)
# Out:
# [(Document(page_content='Tonight. I call on the Senate to: Pass the Freedom to Vote Act. Pass the John Lewis Voting Rights Act. And while you’re at it, pass the Disclose Act so Americans can know who is funding our elections. \n\nTonight, I’d like to honor someone who has dedicated his life to serve this country: Justice Stephen Breyer—an Army veteran, Constitutional scholar, and retiring Justice of the United States Supreme Court. Justice Breyer, thank you for your service. \n\nOne of the most serious constitutional responsibilities a President has is nominating someone to serve on the United States Supreme Court. \n\nAnd I did that 4 days ago, when I nominated Circuit Court of Appeals Judge Ketanji Brown Jackson. One of our nation’s top legal minds, who will continue Justice Breyer’s legacy of excellence.', metadata={'source': 'state_of_the_union.txt'}), 0.907638430595398), (Document(page_content='A former top litigator in private practice. A former federal public defender. And fro
# ...

# %%
from langchain.docstore.document import Document
from langchain.text_splitter import CharacterTextSplitter
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import Neo4jVector
from langchain_openai import OpenAIEmbeddings

loader = TextLoader("state_of_the_union.txt")

documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

# %%
# The Neo4jVector Module will connect to Neo4j and create a vector index if needed.

db = Neo4jVector.from_documents(docs, OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY), url=url, username=username, password=password,search_type='hybrid')

query = "What did the president say about Ketanji Brown Jackson"
docs_with_score = db.similarity_search_with_score(query, k=2)

# %%
from langchain_community.graphs import Neo4jGraph

NEO4J_URI="bolt://localhost:7687"
NEO4J_USERNAME="gyanesh"
NEO4J_PASSWORD="gyanesh1234"
graph = Neo4jGraph(url=NEO4J_URI, username=NEO4J_USERNAME, password=NEO4J_PASSWORD)

QUERY = "MATCH p=()-[r:PURCHASED]->() RETURN p LIMIT 25"

graph.query(QUERY)
# Out:
# [{'p': [{'country': 'France',
#     'address': "59 rue de l'Abbaye",
#     'contactTitle': 'Accounting Manager',
#     'city': 'Reims',
#     'phone': '26.47.15.10',
#     'contactName': 'Paul Henriot',
#     'companyName': 'Vins et alcools Chevalier',
#     'postalCode': '51100',
#     'customerID': 'VINET',
#     'fax': '26.47.15.11',
#     'region': 'NULL'},
#    'PURCHASED',
#    {'shipCity': 'Reims',
#     'orderID': '10248',
#     'freight': '32.38',
#     'requiredDate': '1996-08-01 00:00:00.000',
#     'employeeID': '5',
#     'shipPostalCode': '51100',
#     'shipName': 'Vins et alcools Chevalier',
#     'shipCountry': 'France',
#     'shipAddress': "59 rue de l'Abbaye",
#     'shipVia': '3',
#     'customerID': 'VINET',
#     'shipRegion': 'NULL',
#     'orderDate': '1996-07-04 00:00:00.000',
#     'shippedDate': '1996-07-16 00:00:00.000'}]},
#  {'p': [{'country': 'Germany',
#     'address': 'Luisenstr. 48',
#     'contactTitle': 'Marketing Manager',
# ...
